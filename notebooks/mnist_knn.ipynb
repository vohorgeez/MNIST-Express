# %%
from mnist_express.data import load_data
from mnist_express.train import compare_plain_vs_pca
from mnist_express.config import get_settings
from mnist_express.metrics import plot_explained_variance

settings = get_settings()
X_train, X_test, y_train, y_test = load_data()

results = compare_plain_vs_pca(
    X_train, y_train, X_test, y_test, settings
)

print("PLAIN:", results["plain"])
print("PCA:", results["pca"])

plot_explained_variance(results["pca"]["explained_variance"])
